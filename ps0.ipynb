# %%
import os, zipfile
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import mapclassify

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

#from google.colab import data_table
#data_table.enable_dataframe_formatter() #this enables spreadsheet view upon calling dataframe (without() )

# %%
! wget -q -O usacanab.zip https://github.com/iyeboah22/GIS-DS/blob/7ec17d5827feacb998cdcbc43522b79a0c6dd966/usacanab.zip

zip_ref = zipfile.ZipFile('usacanab.zip', 'r');
zip_ref.extractall();
zip_ref.close() #just unzipping
na_shp = gpd.read_file('USACANAB.SHP') #load the shapefile with gpd as njC
# Out:
# zsh:1: command not found: wget

# %%
#first map
na_shp.plot()
# Out:
# <Axes: >

# %%
! wget https://github.com/iyeboah22/GIS-DS/blob/7ec17d5827feacb998cdcbc43522b79a0c6dd966/Mental%20health%20Depression%20disorder%20Data.csv

dataset = pd.read_csv("Mental health Depression disorder Data.csv")
dataset.head()
# Out:
# zsh:1: command not found: wget
# /var/folders/qg/d9jygk1d6dv3c6s4t5ymzpgr0000gn/T/ipykernel_94410/1708844858.py:3: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv("Mental health Depression disorder Data.csv")
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# ...

# %% [markdown]
# My next step is filtering the data to NA & focusing on mapping depression rates
